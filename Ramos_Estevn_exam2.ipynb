# %% [markdown]
# # **CS 4361/5361 Machine Learning - Exam 2**
#
# Please rename the notebook as *lastname_firstname_exam2.ipynb* before submitting.
#
# Good luck!!

# %% [markdown]
# ## **Question 1**
#
# The following code cell downloads the iris dataset, a commonly used toy dataset.

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

# %% [markdown]
# ### 1. Write functions to return the number of features, the number of examples, and the number of classes in the dataset.

# %%
def features(X,y):
  return X.shape[1]

def examples(X,y):
  return X.shape[0]

def classes(X,y):
  return max(y) +1

print('Number of features:', features(X,y))
print('Number of examples:',examples(X,y))
print('Number of classes:',classes(X,y))
# Out:
# Number of features: 4
# Number of examples: 150
# Number of classes: 3

# %% [markdown]
# ### 2. Write a code cell to randomly split the data into a training and a test set. Keep 80% of the examples for training and the rest for testing.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=4534
)

# %% [markdown]
# ### 3. Write a code cell to classify the data using a random forest and display the resulting test set accuracy.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score


model = RandomForestClassifier(n_estimators = 20, max_depth=5, random_state=0)
model.fit(x_train,y_train)
pred = model.predict(x_test)

print("Accuracy: " , accuracy_score(pred,y_test))
# Out:
# Accuracy:  0.9666666666666667

# %% [markdown]
# ### 4. Write a code cell to classify the data using a support vector classifier and display the resulting confusion matrix.

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
model = SVC()
model.fit(x_train,y_train)
pred = model.predict(x_test)

confusion_matrix = confusion_matrix(y_test,pred)
print(confusion_matrix)
# Out:
# [[10  0  0]
#  [ 0  5  1]
#  [ 0  1 13]]

# %% [markdown]
# ### 5. Write a code cell to classify the data using a decision tree and only one feature in the dataset (you may choose any of the features). Display the resulting test set accuracy.

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(x_train[:,3].reshape(-1,1) , y_train)
pred = model.predict(x_test[:,3].reshape(-1,1))
print("accuracy score: " , accuracy_score(pred, y_test))
# Out:
# accuracy score:  0.9666666666666667

# %% [markdown]
# ## **Question 2**
#
# The following code implements a vgg-style network to classify the CIFAR-10 dataset.
#
# Evaluate the effects of each of the following changes to the original architecture and/or data.
#
# *   Train the network using the test set and evaluate it using the training set.
# *   Increasing the initial learning rate to 10 times the default.
# *   Replacing the activation in the classification layer by sigmoid.
# *   Inserting a dropout layer that will set to zero 20% of the activations between the dense layer and the classification layer.
# *   Converting the images to gray level by averaging their 3 color channels.
# *   Converting the problem to a binary classification problems where the classes are animals and objects.

# %% [markdown]
# ### 0. Original program

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt 
from keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.activations import *
from keras.utils.vis_utils import plot_model

# %%
def plot_results(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  fig, ax = plt.subplots()
  ax.plot(accuracy,label = 'train')
  ax.plot(val_accuracy,label = 'test')
  ax.set_title('Accuracy')
  ax.legend(loc='lower right')
  fig, ax = plt.subplots()
  ax.plot(loss,label = 'train')
  ax.plot(val_loss,label = 'test')
  ax.set_title('Loss')
  ax.legend(loc='upper right')
  plt.show()

# %% [markdown]
# Read data

# %%
(x_train, y_train_class), (x_test, y_test_class) = tf.keras.datasets.cifar10.load_data()
x_train = np.float32(x_train)/255
x_test = np.float32(x_test)/255

# Convert y to one-hot
y_train = tf.keras.utils.to_categorical(y_train_class, 10)
y_test = tf.keras.utils.to_categorical(y_test_class, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Examine data dimensions

# %%
print(x_train.shape, y_train_class.shape, y_train.shape)
print(x_test.shape, y_test_class.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (50000, 10)
# (10000, 32, 32, 3) (10000, 1) (10000, 10)

# %% [markdown]
# Original Network

# %%
def vgg3(input_shape=(32,32,3)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dense(10, activation='softmax'))
  return model

cnn = vgg3(input_shape= x_train.shape[1:])
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    x_train, y_train,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 16s 18ms/step - loss: 1.6540 - accuracy: 0.3891 - val_loss: 1.3877 - val_accuracy: 0.4838
# Epoch 2/10
# 196/196 [==============================] - 3s 16ms/step - loss: 1.2296 - accuracy: 0.5596 - val_loss: 1.0999 - val_accuracy: 0.6059
# Epoch 3/10
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0085 - accuracy: 0.6440 - val_loss: 0.9636 - val_accuracy: 0.6608
# Epoch 4/10
# 196/196 [==============================] - 3s 16ms/step - loss: 0.8452 - accuracy: 0.7023 - val_loss: 0.8155 - val_accuracy: 0.7140
# Epoch 5/10
# 196/196 [==============================] - 3s 16ms/step - loss: 0.7357 - accuracy: 0.7435 - val_loss: 0.7795 - val_accuracy: 0.7321
# Epoch 6/10
# 196/196 [==============================] - 3s 16ms/step - loss: 0.6325 - accuracy: 0.7800 - val_loss: 0.7873 - val_accuracy: 0.7343
# Epoch 7/10
# 196/196 [==============================] - 3s 15ms/step - loss: 0.5572 - accuracy: 0.8069 - val_loss: 0.7145 - val_accuracy: 0.7570
# Epoch 8/10
# 196/196 [==============================] - 3s 15ms/step - loss: 0.4842 - accuracy: 0.8317 - val_loss: 0.7578 - val_accuracy: 0.7422
# Epoch 9/10
# 196/196 [==============================] - 3s 16ms/step - loss: 0.4055 - accuracy: 0.8592 - val_loss: 0.7930 - val_accuracy: 0.7573
# Epoch 10/10
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3411 - accuracy: 0.8810 - val_loss: 0.7854 - val_accuracy: 0.7614
# Final accuracy on training set: 0.8810
# Final accuracy on test set: 0.7614
# Mean accuracy in last 5 epochs: 0.7504

# %% [markdown]
# ### 1. Swapping training and test sets.

# %%
def vgg3(input_shape=(32,32,3)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dense(10, activation='softmax'))
  return model

cnn = vgg3(input_shape= x_train.shape[1:])
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    x_test, y_test,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(x_train, y_train),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 40/40 [==============================] - 3s 64ms/step - loss: 2.0833 - accuracy: 0.2237 - val_loss: 1.8834 - val_accuracy: 0.2893
# Epoch 2/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.7924 - accuracy: 0.3438 - val_loss: 1.6903 - val_accuracy: 0.3729
# Epoch 3/10
# 40/40 [==============================] - 1s 37ms/step - loss: 1.5726 - accuracy: 0.4222 - val_loss: 1.5350 - val_accuracy: 0.4380
# Epoch 4/10
# 40/40 [==============================] - 1s 37ms/step - loss: 1.4810 - accuracy: 0.4596 - val_loss: 1.5117 - val_accuracy: 0.4500
# Epoch 5/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.3894 - accuracy: 0.4956 - val_loss: 1.5582 - val_accuracy: 0.4157
# Epoch 6/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.3162 - accuracy: 0.5278 - val_loss: 1.3676 - val_accuracy: 0.5119
# Epoch 7/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.2173 - accuracy: 0.5652 - val_loss: 1.3533 - val_accuracy: 0.5130
# Epoch 8/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.1808 - accuracy: 0.5778 - val_loss: 1.3269 - val_accuracy: 0.5297
# Epoch 9/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.1008 - accuracy: 0.6070 - val_loss: 1.3062 - val_accuracy: 0.5397
# Epoch 10/10
# 40/40 [==============================] - 1s 36ms/step - loss: 1.0542 - accuracy: 0.6216 - val_loss: 1.1954 - val_accuracy: 0.5813
# Final accuracy on training set: 0.6216
# Final accuracy on test set: 0.5813
# Mean accuracy in last 5 epochs: 0.5351

# %% [markdown]
# ### 2. Increasing the learning rate (default rate is 0.001)

# %%
def vgg3(input_shape=(32,32,3)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dense(10, activation='softmax'))
  return model

lr = .003
cnn = vgg3(input_shape= x_train.shape[1:])
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    x_train, y_train,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 128)               262272
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 3s 15ms/step - loss: 1.9491 - accuracy: 0.2708 - val_loss: 1.6169 - val_accuracy: 0.4113
# Epoch 2/10
# 196/196 [==============================] - 3s 14ms/step - loss: 1.3852 - accuracy: 0.4954 - val_loss: 1.2345 - val_accuracy: 0.5546
# Epoch 3/10
# 196/196 [==============================] - 3s 14ms/step - loss: 1.1327 - accuracy: 0.5934 - val_loss: 1.0603 - val_accuracy: 0.6177
# Epoch 4/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.9628 - accuracy: 0.6599 - val_loss: 0.9715 - val_accuracy: 0.6600
# Epoch 5/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.8440 - accuracy: 0.7021 - val_loss: 0.9243 - val_accuracy: 0.6767
# Epoch 6/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.7606 - accuracy: 0.7311 - val_loss: 0.8847 - val_accuracy: 0.6942
# Epoch 7/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.6892 - accuracy: 0.7564 - val_loss: 0.8701 - val_accuracy: 0.7067
# Epoch 8/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.6367 - accuracy: 0.7776 - val_loss: 0.8756 - val_accuracy: 0.7084
# Epoch 9/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.5784 - accuracy: 0.7961 - val_loss: 0.8545 - val_accuracy: 0.7182
# Epoch 10/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.5360 - accuracy: 0.8098 - val_loss: 0.8917 - val_accuracy: 0.7161
# Final accuracy on training set: 0.8098
# Final accuracy on test set: 0.7161
# Mean accuracy in last 5 epochs: 0.7087

# %% [markdown]
# ### 3. Replacing activation in classification layer by sigmoid.

# %%
def vgg3(input_shape=(32,32,3)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dense(10, activation='sigmoid'))
  return model

cnn = vgg3(input_shape= x_train.shape[1:])
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    x_train, y_train,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_8 (Dense)             (None, 128)               262272
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 4s 15ms/step - loss: 1.7121 - accuracy: 0.3700 - val_loss: 1.4169 - val_accuracy: 0.4808
# Epoch 2/10
# 196/196 [==============================] - 3s 14ms/step - loss: 1.2164 - accuracy: 0.5683 - val_loss: 1.0720 - val_accuracy: 0.6180
# Epoch 3/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.9819 - accuracy: 0.6544 - val_loss: 0.9600 - val_accuracy: 0.6599
# Epoch 4/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.8275 - accuracy: 0.7083 - val_loss: 0.8605 - val_accuracy: 0.6967
# Epoch 5/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.7079 - accuracy: 0.7524 - val_loss: 0.8240 - val_accuracy: 0.7175
# Epoch 6/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.6169 - accuracy: 0.7852 - val_loss: 0.7686 - val_accuracy: 0.7386
# Epoch 7/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.5333 - accuracy: 0.8135 - val_loss: 0.7490 - val_accuracy: 0.7538
# Epoch 8/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.4599 - accuracy: 0.8410 - val_loss: 0.7403 - val_accuracy: 0.7464
# Epoch 9/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3821 - accuracy: 0.8656 - val_loss: 0.7689 - val_accuracy: 0.7530
# Epoch 10/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3269 - accuracy: 0.8843 - val_loss: 0.7738 - val_accuracy: 0.7577
# Final accuracy on training set: 0.8843
# Final accuracy on test set: 0.7577
# Mean accuracy in last 5 epochs: 0.7499

# %% [markdown]
# ### 4. Inserting a dropout layer that will set to zero 20% of the activations between the dense layer and the classification layer.

# %%
def vgg3(input_shape=(32,32,3)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(10, activation='softmax'))
  return model

cnn = vgg3(input_shape= x_train.shape[1:])
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    x_train, y_train,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_15 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_16 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_17 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dense_10 (Dense)            (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 4s 15ms/step - loss: 1.7001 - accuracy: 0.3701 - val_loss: 1.3856 - val_accuracy: 0.4936
# Epoch 2/10
# 196/196 [==============================] - 3s 14ms/step - loss: 1.2529 - accuracy: 0.5466 - val_loss: 1.0899 - val_accuracy: 0.6136
# Epoch 3/10
# 196/196 [==============================] - 3s 14ms/step - loss: 1.0388 - accuracy: 0.6307 - val_loss: 0.9327 - val_accuracy: 0.6681
# Epoch 4/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.8947 - accuracy: 0.6855 - val_loss: 0.8402 - val_accuracy: 0.7029
# Epoch 5/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.7828 - accuracy: 0.7233 - val_loss: 0.8147 - val_accuracy: 0.7179
# Epoch 6/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.6913 - accuracy: 0.7566 - val_loss: 0.7388 - val_accuracy: 0.7460
# Epoch 7/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.6170 - accuracy: 0.7826 - val_loss: 0.6950 - val_accuracy: 0.7632
# Epoch 8/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.5613 - accuracy: 0.8011 - val_loss: 0.6971 - val_accuracy: 0.7644
# Epoch 9/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.5008 - accuracy: 0.8227 - val_loss: 0.6867 - val_accuracy: 0.7706
# Epoch 10/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.4467 - accuracy: 0.8428 - val_loss: 0.6853 - val_accuracy: 0.7753
# Final accuracy on training set: 0.8428
# Final accuracy on test set: 0.7753
# Mean accuracy in last 5 epochs: 0.7639

# %% [markdown]
# ### 5. Converting the images to gray level by averaging their 3 color channels.

# %%
print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
def vgg3(input_shape=(32,32,1)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dense(10, activation='softmax'))
  return model

import numpy as np
gray_train = np.mean(x_train , axis= 3)
gray_test = np.mean(x_test , axis= 3)

print(gray_train.shape)

cnn = vgg3()
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    gray_train, y_train,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(gray_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# (50000, 32, 32)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 32, 32, 32)        320
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_8 (Dense)             (None, 128)               262272
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 549,994
# Trainable params: 549,994
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 3s 14ms/step - loss: 1.7930 - accuracy: 0.3450 - val_loss: 1.4997 - val_accuracy: 0.4531
# Epoch 2/10
# 196/196 [==============================] - 3s 13ms/step - loss: 1.3067 - accuracy: 0.5387 - val_loss: 1.1848 - val_accuracy: 0.5830
# Epoch 3/10
# 196/196 [==============================] - 3s 13ms/step - loss: 1.0781 - accuracy: 0.6227 - val_loss: 1.0306 - val_accuracy: 0.6460
# Epoch 4/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.9148 - accuracy: 0.6821 - val_loss: 0.9172 - val_accuracy: 0.6829
# Epoch 5/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.7974 - accuracy: 0.7236 - val_loss: 0.9314 - val_accuracy: 0.6817
# Epoch 6/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.6996 - accuracy: 0.7572 - val_loss: 0.8479 - val_accuracy: 0.7117
# Epoch 7/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.6162 - accuracy: 0.7847 - val_loss: 0.8362 - val_accuracy: 0.7193
# Epoch 8/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.5312 - accuracy: 0.8163 - val_loss: 0.7960 - val_accuracy: 0.7380
# Epoch 9/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.4626 - accuracy: 0.8399 - val_loss: 0.8187 - val_accuracy: 0.7396
# Epoch 10/10
# 196/196 [==============================] - 3s 13ms/step - loss: 0.3927 - accuracy: 0.8632 - val_loss: 0.8742 - val_accuracy: 0.7311
# Final accuracy on training set: 0.8632
# Final accuracy on test set: 0.7311
# Mean accuracy in last 5 epochs: 0.7279

# %% [markdown]
# ### 6. Converting the problem to binary classification.

# %%
class_names= ['airplane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship','truck']

animals = ['bird', 'cat', 'deer', 'dog', 'frog', 'horse'] # Class 0, y_train_class in [2,3,4,5,6,7]
objects = ['airplane', 'car', 'ship','truck']             # Class 1, y_train_class in [0,1,8,9]

br1 = [ 2 > y_train_class] 
br2 = [ 7 < y_train_class]
new_y_train = br1 or br2
binary_y_train = np.where(new_y_train, 1,0)

br1 = [ 2 > y_test_class] 
br2 = [ 7 < y_test_class]
new_y_test = br1 or br2
binary_y_test = np.where(new_y_test, 1,0)

binary_y_train = binary_y_train.reshape(-1)
binary_y_test = binary_y_test.reshape(-1)

binary_y_train = tf.keras.utils.to_categorical(binary_y_train, 2)
binary_y_test  = tf.keras.utils.to_categorical(binary_y_test , 2)

# %%
binary_y_train = np.where(y_train_class <2|y_train_class > 7,1,0)
binary_y_test = np.where((y_test_class <2)|(y_test_class > 7),1,0)

binary_y_train = tf.keras.utils.to_categorical(binary_y_train, 2)
binary_y_test  = tf.keras.utils.to_categorical(binary_y_test , 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8433cd68dd9c> in <module>()
# ----> 1 binary_y_train = np.where(y_train_class <2|y_train_class > 7,1,0)
#       2 binary_y_test = np.where((y_test_class <2)|(y_test_class > 7),1,0)
#       3
#       4 binary_y_train = tf.keras.utils.to_categorical(binary_y_train, 2)
#       5 binary_y_test  = tf.keras.utils.to_categorical(binary_y_test , 2)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
def vgg3(input_shape=(32,32,3)):
  model = tf.keras.models.Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same', activation="relu"))
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation="relu"))
  model.add(Conv2D(128, kernel_size=(3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dense(2, activation='softmax'))
  return model

cnn = vgg3(input_shape= x_train.shape[1:])
cnn.summary() 
cnn.compile(optimizer=tf.keras.optimizers.Adam(), loss="categorical_crossentropy", metrics=["accuracy"])
    
history = cnn.fit(
    x_train, binary_y_train,
    epochs =  10, 
    batch_size=256, 
    verbose = 1,
    validation_data=(x_test, binary_y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))

plot_results(history)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_66 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_67 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_33 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_68 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_69 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_34 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_71 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_35 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 2048)              0
#
#  dense_22 (Dense)            (None, 128)               262272
#
#  dense_23 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 549,538
# Trainable params: 549,538
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 4s 15ms/step - loss: 0.3991 - accuracy: 0.8239 - val_loss: 0.3147 - val_accuracy: 0.8556
# Epoch 2/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2860 - accuracy: 0.8745 - val_loss: 0.2653 - val_accuracy: 0.8860
# Epoch 3/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2448 - accuracy: 0.8985 - val_loss: 0.2279 - val_accuracy: 0.9045
# Epoch 4/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2031 - accuracy: 0.9182 - val_loss: 0.2007 - val_accuracy: 0.9171
# Epoch 5/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.1774 - accuracy: 0.9288 - val_loss: 0.1916 - val_accuracy: 0.9243
# Epoch 6/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.1510 - accuracy: 0.9415 - val_loss: 0.1883 - val_accuracy: 0.9271
# Epoch 7/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.1295 - accuracy: 0.9499 - val_loss: 0.1817 - val_accuracy: 0.9300
# Epoch 8/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.1099 - accuracy: 0.9574 - val_loss: 0.1985 - val_accuracy: 0.9260
# Epoch 9/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.0894 - accuracy: 0.9659 - val_loss: 0.1825 - val_accuracy: 0.9336
# Epoch 10/10
# 196/196 [==============================] - 3s 14ms/step - loss: 0.0718 - accuracy: 0.9728 - val_loss: 0.2233 - val_accuracy: 0.9322
# Final accuracy on training set: 0.9728
# Final accuracy on test set: 0.9322
# Mean accuracy in last 5 epochs: 0.9298
