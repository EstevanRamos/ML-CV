# %%
pip install pyOfferUp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyOfferUp
#   Downloading pyOfferUp-0.3.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyOfferUp) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyOfferUp) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyOfferUp) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pyOfferUp) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyOfferUp) (3.4)
# Building wheels for collected packages: pyOfferUp
#   Building wheel for pyOfferUp (setup.py) ... done
#   Created wheel for pyOfferUp: filename=pyOfferUp-0.3-py3-none-any.whl size=25596 sha256=c2c5e95e0bc7d448db8f748a5a5b44d6a6287558f96bf5296c4fc636eb845b31
#   Stored in directory: /root/.cache/pip/wheels/4d/dc/83/2fb047d54cb32df9d0181650c9e3819d100057c4f04afd7827
# Successfully built pyOfferUp
# Installing collected packages: pyOfferUp
# Successfully installed pyOfferUp-0.3

# %%
from pyOfferUp import places

print(places.available_cities('Texas'))
# Out:
# ['Abilene', 'Addison', 'Amarillo', 'Arlington', 'Austin', 'Baytown', 'Beaumont', 'Brownsville', 'Bryan', 'Carrollton', 'Cedar Hill', 'Channelview', 'Conroe', 'Corpus Christi', 'Dallas', 'Denton', 'Duncanville', 'El Paso', 'Euless', 'Farmers Branch', 'Fort Worth', 'Frisco', 'Garland', 'Grand Prairie', 'Harlingen', 'Houston', 'Humble', 'Irving', 'Katy', 'Killeen', 'Laredo', 'Lewisville', 'Longview', 'Lubbock', 'Lufkin', 'Mansfield', 'Mcallen', 'McKinney', 'Mesquite', 'Midland', 'Midlothian', 'Nacogdoches', 'Odessa', 'Pearland', 'Pflugerville', 'Plano', 'Port Arthur', 'Richardson', 'Round Rock', 'San Angelo', 'San Antonio', 'San Marcos', 'Sherman', 'Stafford', 'Sugar Land', 'Sweetwater', 'Temple', 'Tomball', 'Tyler', 'Victoria', 'Waco', 'Weslaco', 'Wichita Falls']

# %%
from pyOfferUp import fetch

# %%
from pyOfferUp import fetch

posts = fetch.get_listings(query="luigis mansion", state="Texas", city="El Paso", limit=100)

# %%
# Out:
# []
