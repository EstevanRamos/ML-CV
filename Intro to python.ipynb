# %% [markdown]
# # INTRODUCTION TO PYTHON

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('/content/sample_data/california_housing_train.csv') as f:
    #gets rid of the header
    lines = (line for line in f if not line.startswith('#'))
    #loads data into numpy array
    housing_data = np.loadtxt(lines, delimiter=',', skiprows=1)

# %% [markdown]
# The data pertains to the houses found in a given California district and some summary stats about them based on the 1990 census data.

# %% [markdown]
# 1. longitude: A measure of how far west a house is; a higher value is farther west
# 2. latitude: A measure of how far north a house is; a higher value is farther north
# 3. housingMedianAge: Median age of a house within a block; a lower number is a newer building
# 4. totalRooms: Total number of rooms within a block
# 5. totalBedrooms: Total number of bedrooms within a block
# 6. population: Total number of people residing within a block
# 7. households: Total number of households, a group of people residing within a home unit, for a block
# 8. medianIncome: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
# 9. medianHouseValue: Median house value for households within a block (measured in US Dollars)
# 10. oceanProximity: Location of the house w.r.t ocean/sea MISSING THIS ONE

# %%
housing_data

# %%
np.shape(housing_data)

# %%
print(housing_data[0,0])

# %%
print(housing_data[0])

# %%
print(housing_data[: , 7])

# %%
housing_data[:,7]

# %%
plt.plot(housing_data[:, 7])
plt.ylabel('median income')
plt.show()

# %%
#third argument serves as the color and shape
plt.plot(housing_data[:100, 0] ,housing_data[:100, 1], 'r*')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.show()

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %% [markdown]
# ![image.png](data:image/png;base64,...
# )

# %%
fig, ax = plt.subplots()
ax.bar(np.arange(100),housing_data[:100, 8])

# %%
fig, ax = plt.subplots()
ax.barh(np.arange(100),housing_data[:100, 8])

# %%
n_bins = 10
fig, ax = plt.subplots(2)  # Create a figure containing a single axes.
ax[0].hist(housing_data[:,5], bins=n_bins)
ax[1].hist(housing_data[:,6], bins=n_bins)
