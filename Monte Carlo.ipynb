# %% [markdown]
# # Objective:	To	implement	and	experiment	with	Monte	Carlo	Tree	Search as	a	method	for	planning/strategic	reasoning,	using	Connect	Four	as	a	sample	domain.

# %%
from google.colab import files
files.upload()

# %%
import sys
import random
import numpy as np
import copy
import math
import time
from collections import defaultdict

# %%
def read_game_state(file_path):
    """
    Reads the game state from a file.
    """
    with open(file_path, 'r') as file:
        algorithm = file.readline().strip()
        player = file.readline().strip()
        board = [list(file.readline().strip()) for _ in range(6)]
    return algorithm, player, board

# %%
def find_legal_moves(board):
    """
    Finds legal moves based on the current board state.
    Legal moves are columns that are not full (i.e., do not have a piece in the top row).
    """
    return [col for col in range(7) if board[0][col] == 'O']

# %%
def uniform_random_move(legal_moves):
    """
    Selects a legal move using the uniform random strategy.
    """
    return random.choice(legal_moves) + 1  # Adding 1 to convert 0-based index to 1-based column number

# %%
class MonteCarloTreeSearchNode():
  """
  state: For our game it represents the board state.
  parent: It is None for the root node and for other nodes it is equal to the node it is derived from. For the first turn as you have seen from the game it is None.
  children: It contains all possible actions from the current node.
  parent_action: None for the root node and for other nodes it is equal to the action which it’s parent carried out.
  _number_of_visits: Number of times current node is visited
  results: It’s a dictionary
  _untried_actions: Represents the list of all possible actions
  action: Move which has to be carried out.
  """
  def __init__(self, state, parent=None, parent_action=None, verbosity = 0):
    self.state = state
    self.parent = parent
    self.parent_action = parent_action
    self.children = []
    self._number_of_visits = 0
    self._results = defaultdict(int)
    self._results[1] = 0
    self._results[-1] = 0
    self._untried_actions = None
    self._untried_actions = self.untried_actions()
    self.verbosity = verbosity # 0 = None , 1 = Brief, 2 = Verbose
    return

  def untried_actions(self):
    """
    get any possible actions
    """
    self._untried_actions = self.get_legal_actions()
    return self._untried_actions

  def q(self):
      wins = self._results[1]
      losses = self._results[-1]
      return wins - losses

  def n(self):
      return self._number_of_visits

  def UCB(self):
    if self.n() == 0: return math.sqrt(2)
    return self._results[1] / self.n() + math.sqrt(math.log(self.parent.n())/self.n())

  def expand(self):
      """
      From the present state, next state is generated depending on the action which is carried out.
      In this step all the possible child nodes corresponding to generated states are appended to the children array and the child_node is returned.
      The states which are possible from the present state are all generated and the child_node corresponding to this generated state is returned.
      """
      if self.verbosity == 2:
        print('adding children')
      while len(self._untried_actions) != 0:
        action = self._untried_actions.pop()
        next_state = self.move(action)
        child_node = MonteCarloTreeSearchNode(next_state, parent=self, parent_action=action, verbosity=self.verbosity)
        self.children.append(child_node)

  def is_terminal_node(self):
      """
      This is used to check if the current node is terminal or not.
      Terminal node is reached when the game is over.
      """
      return self.is_game_over()

  def rollout(self):
      """
      From the current state, entire game is simulated till there is an outcome for the game.
      the outcome of the game is returned
      """
      if self.verbosity == 2:
        print('simulating...')
      current_node = copy.deepcopy(self)
      while not current_node.is_game_over():

        possible_moves = current_node.get_legal_actions()
        action = current_node.rollout_policy(possible_moves)#later its possible to change how we select nodes for simulation
        if self.verbosity == 2:
          print('Move Selected:', action)
        current_node.state = current_node.move(action)

      return current_node.game_result()

  def backpropagate(self, result):
      """
      In this step all the statistics for the nodes are updated.
      """
      if self.verbosity == 2:
        print('backpropogating...')
      self._number_of_visits += 1.
      self._results[result] += 1.
      if self.parent:
        if self.verbosity == 2:
          print('New Values:')
          print('Wi:', self._results[1])
          print('Ni:', self.n())
        self.parent.backpropagate(result)

  def is_fully_expanded(self):
      """
      returns true if all actions are popped from untried actions
      """
      return len(self._untried_actions) == 0

  def best_child(self, c_param=0.1):
      """
      Once fully expanded, this function selects the best child out of the children array.
      """
      possible_children = []
      for child in self.children:
        if child.n() > 0:
          possible_children.append(child)

      choices_weights = [(c.q() / c.n()) + c_param * np.sqrt((2 * np.log(self.n()) / c.n())) for c in possible_children]
      return self.children[np.argmax(choices_weights)]

  def rollout_policy(self, possible_moves):
      """
      randomly selects a move out of possible moves
      """
      return possible_moves[np.random.randint(len(possible_moves))]

  def _tree_policy(self, algo = 'MCTS'):
      """
      Selects node to run rollout.
      """
      if algo == 'MCTS':
        current_node = self
        while len(current_node.children) > 0 : #while node is not leaf
          children = current_node.children
          current_node = random.choice(children)
        return current_node

      elif algo == 'UCT':
        current_node = self
        while len(current_node.children) > 0: # while node is not a leaf
          max_node = None
          max_value= float('-inf')
          possible_children = []

          if current_node.verbosity == 2:
            print('Wi : ' , current_node._results[1])
            print('Ni : ' , current_node.n())

          for node in current_node.children:
            UCB = node.UCB()
            if node.verbosity == 2:
              print('Child UCB Value:' , UCB)

            if UCB > max_value:
              max_value = UCB

          for child in current_node.children:
            if child.UCB() == max_value:
              possible_children.append(child)

          current_node = random.choice(possible_children)
          if current_node.verbosity == 2:
            print('Move Selected:', current_node.parent_action)

        return current_node


  def best_action(self, simulations = 100, c_param=0.1, algo = 'MCTS'):
      """
      This is the best action function which returns the node corresponding to best possible move.
      The step of expansion, simulation and backpropagation are carried out by the code above.
      """
      start_time = time.time()

      for i in range(simulations):
        v = self._tree_policy(algo)#select node based on tree policy
        v.expand()
        reward = v.rollout()
        v.backpropagate(reward)

      if self.verbosity == 1 or self.verbosity == 2:
        print('Number of rollouts:', simulations)
        print('Seconds elapsed: ', time.time()- start_time)

      return self.best_child(c_param)

  def is_game_over(self):
    """
    Returns true or false depending on if game is over
    """
    def check_consecutive(lst):
        count = 1
        for i in range(len(lst) - 1):
            if lst[i] != 'O' and lst[i] == lst[i + 1]:
                count += 1
                if count == 4:
                    return True
            else:
                count = 1
        return False

    def check_rows(board):
        for row in board:
            if check_consecutive(row):
                return True
        return False

    def check_columns(board):
        for col in range(len(board[0])):
            column = [board[row][col] for row in range(len(board))]
            if check_consecutive(column):
                return True
        return False

    def check_diagonals(board):
        for i in range(len(board) - 3):
            for j in range(len(board[0]) - 3):
                if board[i][j] != 'O' and board[i][j] == board[i + 1][j + 1] == board[i + 2][j + 2] == board[i + 3][j + 3]:
                    return True
                if board[i][j + 3] != 'O' and board[i][j + 3] == board[i + 1][j + 2] == board[i + 2][j + 1] == board[i + 3][j]:
                    return True
        return False

    if check_rows(self.state) or check_columns(self.state) or check_diagonals(self.state):
      return True

    if len(find_legal_moves(self.state)) == 0:  # Assuming find_legal_moves function is defined elsewhere
      return True

    return False

  def game_result(self):
    """
    Returns 1, 0, or -1 depending on the game state:
    1 for a win, 0 for a tie, and -1 for a loss.
    """
    def get_winner(player):
      if player == 'Y':
        return 1
      else:
        return -1

    # Check for horizontal wins.
    for row in self.state:
      for i in range(len(row) - 3):
        if row[i] == row[i + 1] == row[i + 2] == row[i + 3] and row[i] != 'O':
          return get_winner(row[i])

    # Check for vertical wins.
    for col in range(len(self.state[0])):
      for i in range(len(self.state) - 3):
        if self.state[i][col] == self.state[i + 1][col] == self.state[i + 2][col] == self.state[i + 3][col] and self.state[i][col] != 'O':
          return get_winner(self.state[i][col])

    # Check for diagonal wins.
    for i in range(len(self.state) - 3):
      for j in range(len(self.state[0]) - 3):
        if self.state[i][j] == self.state[i + 1][j + 1] == self.state[i + 2][j + 2] == self.state[i + 3][j + 3] and self.state[i][j] != 'O':
          return get_winner(self.state[i][j])

        if self.state[i][j + 3] == self.state[i + 1][j + 2] == self.state[i + 2][j + 1] == self.state[i + 3][j] and self.state[i][j + 3] != 'O':
          return get_winner(self.state[i][j + 3])

    #in case of draw
    if len(find_legal_moves(self.state)) == 0:
      return 0

    # If there is no winner, return None.
    return None



  def move(self, action):
      """
      Given an action, Return a new state after that action occurs
      ASSUMES YELLOW ALWAYS GOES FIRST
      """
      #calculate which players turn it is
      b = np.array(self.state)
      num_ys = (b == 'Y').sum()
      num_rs = (b == 'R').sum()
      player = 'R' if num_ys > num_rs else 'Y'

      #copy the new board
      board = copy.deepcopy(self.state)
      row = 0
      #drop piece
      for i in range(len(board[0])-1):
        if board[i][action] == 'O':
          row = i

      board[row][action] = player
      return board

  def get_legal_actions(self):

      '''
      gets legal moves of the state
      '''
      return find_legal_moves(self.state)

# %%
def main(file_path, verbosity, simulations):
    # Read game state
    algorithm, player, board = read_game_state(file_path)

    #for testing
    algorithm = 'UCT'

    match verbosity:
      case 'None':
        v = 0
      case 'Brief':
        v = 1
      case 'Verbose':
        v = 2

    # Select move based on the algorithm
    if algorithm == 'UR':
        # Find legal moves
        legal_moves = find_legal_moves(board)
        move = uniform_random_move(legal_moves)

    if algorithm == 'PMCGS':
      root = MonteCarloTreeSearchNode(state = board, verbosity=v)
      selected_node = root.best_action(simulations = simulations)
      print(selected_node.parent_action)

    if algorithm == 'UCT':
      root = MonteCarloTreeSearchNode(state = board, verbosity=v)
      selected_node = root.best_action(simulations = simulations, algo='UCT')
      print(selected_node.parent_action)


if __name__ == "__main__":
    file_path = './test1.txt'  # The name of the input file
    verbosity = 'Verbose'  # Verbose, Brief, or None
    simulations = 100  # Number of simulations, not used for UR but required for the script

    main(file_path, verbosity, simulations)
# Out:
# Streaming output truncated to the last 5000 lines.
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.301056344430076
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.318892046038839
# Move Selected: 1
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 5
# Move Selected: 1
# Move Selected: 0
# Move Selected: 3
# Move Selected: 3
# Move Selected: 2
# Move Selected: 0
# Move Selected: 2
# Move Selected: 1
# Move Selected: 0
# Move Selected: 1
# Move Selected: 5
# Move Selected: 3
# Move Selected: 6
# Move Selected: 0
# Move Selected: 4
# Move Selected: 6
# Move Selected: 5
# Move Selected: 3
# Move Selected: 4
# Move Selected: 5
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# Wi :  35.0
# Ni :  48.0
# Child UCB Value: 1.303243529998623
# Child UCB Value: 1.2799092011006468
# Child UCB Value: 1.4081973127139746
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.303243529998623
# Child UCB Value: 2.9675367876885788
# Child UCB Value: 1.3205073896349244
# Move Selected: 1
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 1
# adding children
# simulating...
# Move Selected: 3
# Move Selected: 1
# Move Selected: 1
# Move Selected: 3
# Move Selected: 4
# Move Selected: 3
# Move Selected: 3
# Move Selected: 5
# Move Selected: 2
# Move Selected: 0
# Move Selected: 4
# Move Selected: 5
# Move Selected: 2
# Move Selected: 0
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# Wi :  35.0
# Ni :  49.0
# Child UCB Value: 1.305379858421957
# Child UCB Value: 1.2822494316360455
# Child UCB Value: 1.409430722504264
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.305379858421957
# Child UCB Value: 1.8949588341794583
# Child UCB Value: 1.3220851727400227
# Move Selected: 1
# Wi :  1.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 0.8325546111576977
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 2
# Move Selected: 4
# Move Selected: 2
# Move Selected: 6
# Move Selected: 4
# Move Selected: 3
# Move Selected: 5
# Move Selected: 1
# Move Selected: 5
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 3.0
# backpropogating...
# Wi :  36.0
# Ni :  50.0
# Child UCB Value: 1.307467543767565
# Child UCB Value: 1.2845363763495707
# Child UCB Value: 1.410636048200534
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.307467543767565
# Child UCB Value: 1.8085982182388478
# Child UCB Value: 1.3236270305513425
# Move Selected: 1
# Wi :  2.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 2.048147073968205
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.048147073968205
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 1
# Move Selected: 3
# Move Selected: 5
# Move Selected: 0
# Move Selected: 0
# Move Selected: 2
# Move Selected: 2
# Move Selected: 4
# Move Selected: 1
# Move Selected: 5
# Move Selected: 0
# Move Selected: 6
# Move Selected: 0
# Move Selected: 0
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 4.0
# backpropogating...
# Wi :  37.0
# Ni :  51.0
# Child UCB Value: 1.3095086609300242
# Child UCB Value: 1.2867723081743505
# Child UCB Value: 1.4118144877437273
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3095086609300242
# Child UCB Value: 1.74144158082112
# Child UCB Value: 1.325134495480086
# Move Selected: 1
# Wi :  3.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.1774100225154747
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 6
# Move Selected: 4
# Move Selected: 1
# Move Selected: 6
# Move Selected: 4
# Move Selected: 4
# Move Selected: 4
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 5.0
# backpropogating...
# Wi :  38.0
# Ni :  52.0
# Child UCB Value: 1.3115051569543912
# Child UCB Value: 1.288959359991381
# Child UCB Value: 1.4129671652608318
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3115051569543912
# Child UCB Value: 1.6889593599913808
# Child UCB Value: 1.326609005514328
# Move Selected: 1
# Wi :  4.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7324474753487107
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.2686362411795196
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# adding children
# simulating...
# Move Selected: 5
# Move Selected: 6
# Move Selected: 6
# Move Selected: 2
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 6.0
# backpropogating...
# Wi :  39.0
# Ni :  53.0
# Child UCB Value: 1.3134588612372193
# Child UCB Value: 1.2910995358041797
# Child UCB Value: 1.4140951369544394
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3134588612372193
# Child UCB Value: 1.6467921945705526
# Child UCB Value: 1.328051911752964
# Move Selected: 1
# Wi :  5.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.669283099522925
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3385661990458504
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# adding children
# simulating...
# Move Selected: 2
# Move Selected: 2
# Move Selected: 4
# Move Selected: 1
# Move Selected: 5
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 7.0
# backpropogating...
# Wi :  40.0
# Ni :  54.0
# Child UCB Value: 1.3153714947356077
# Child UCB Value: 1.2931947208267944
# Child UCB Value: 1.415199396419595
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3153714947356077
# Child UCB Value: 1.6120301757506716
# Child UCB Value: 1.3294644852070459
# Move Selected: 1
# Wi :  6.0
# Ni :  7.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6238445558078252
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3949588341794583
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 0
# adding children
# simulating...
# Move Selected: 2
# Move Selected: 1
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 6.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 8.0
# backpropogating...
# Wi :  41.0
# Ni :  55.0
# Child UCB Value: 1.3172446782973943
# Child UCB Value: 1.2952466906090714
# Child UCB Value: 1.4162808794532342
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3172446782973943
# Child UCB Value: 1.5827546525131848
# Child UCB Value: 1.3308479229520358
# Move Selected: 1
# Wi :  7.0
# Ni :  8.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5887050112577374
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.442026886600883
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  6.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.598625002690007
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Move Selected: 0
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 1
# adding children
# simulating...
# Move Selected: 5
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 6.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 7.0
# backpropogating...
# New Values:
# Wi: 8.0
# Ni: 9.0
# backpropogating...
# Wi :  42.0
# Ni :  56.0
# Child UCB Value: 1.3190799402108797
# Child UCB Value: 1.297257119306963
# Child UCB Value: 1.4173404684130184
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3190799402108797
# Child UCB Value: 1.5576648595775584
# Child UCB Value: 1.3322033537036466
# Move Selected: 1
# Wi :  8.0
# Ni :  9.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5602581773912325
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4823038073675112
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  7.0
# Ni :  7.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5694895593212272
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  6.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.598625002690007
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Move Selected: 0
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Move Selected: 1
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# adding children
# simulating...
# Move Selected: 1
# Move Selected: 4
# Move Selected: 2
# Move Selected: 1
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 6.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 7.0
# backpropogating...
# New Values:
# Wi: 8.0
# Ni: 8.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 10.0
# backpropogating...
# Wi :  43.0
# Ni :  57.0
# Child UCB Value: 1.3208787230598835
# Child UCB Value: 1.2992275871918688
# Child UCB Value: 1.4183789961751045
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3208787230598835
# Child UCB Value: 1.5358499247333879
# Child UCB Value: 1.3335318428806384
# Move Selected: 1
# Wi :  9.0
# Ni :  10.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5364915065723368
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5174271293851465
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  8.0
# Ni :  8.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5450349322592394
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  7.0
# Ni :  7.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5694895593212272
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  6.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.598625002690007
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Move Selected: 0
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Move Selected: 1
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# adding children
# simulating...
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 6.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 7.0
# backpropogating...
# New Values:
# Wi: 8.0
# Ni: 8.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 9.0
# backpropogating...
# New Values:
# Wi: 10.0
# Ni: 11.0
# backpropogating...
# Wi :  44.0
# Ni :  58.0
# Child UCB Value: 1.3226423899591708
# Child UCB Value: 1.3011595874811985
# Child UCB Value: 1.419397249734169
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3226423899591708
# Child UCB Value: 1.516652579028165
# Child UCB Value: 1.3348343972099834
# Move Selected: 1
# Wi :  10.0
# Ni :  11.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5161712972344625
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5485138917033876
# Child UCB Value: 1.4142135623730951
# Move Selected: 1
# Wi :  0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 0
# adding children
# simulating...
# Move Selected: 2
# Move Selected: 3
# Move Selected: 6
# Move Selected: 5
# Move Selected: 4
# Move Selected: 0
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 10.0
# Ni: 12.0
# backpropogating...
# Wi :  44.0
# Ni :  59.0
# Child UCB Value: 1.3243722302360061
# Child UCB Value: 1.3030545325622058
# Child UCB Value: 1.4203959734836547
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3243722302360061
# Child UCB Value: 1.4162525275550912
# Child UCB Value: 1.3361119689229737
# Move Selected: 4
# Wi :  17.0
# Ni :  18.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4123370806895
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 0
# adding children
# simulating...
# Move Selected: 2
# Move Selected: 2
# Move Selected: 3
# Move Selected: 1
# Move Selected: 4
# Move Selected: 0
# Move Selected: 4
# Move Selected: 3
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 17.0
# Ni: 19.0
# backpropogating...
# Wi :  44.0
# Ni :  60.0
# Child UCB Value: 1.326069464615628
# Child UCB Value: 1.30491375967239
# Child UCB Value: 1.358947806069193
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.326069464615628
# Child UCB Value: 1.4174526534941845
# Child UCB Value: 1.337365459584948
# Move Selected: 1
# Wi :  10.0
# Ni :  12.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5254528892920214
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.1146539036373577
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  9.0
# Ni :  9.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5240735369841025
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  8.0
# Ni :  8.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5450349322592394
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  7.0
# Ni :  7.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.5694895593212272
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  6.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.598625002690007
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Move Selected: 0
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Move Selected: 1
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 2
# adding children
# simulating...
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 6.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 7.0
# backpropogating...
# New Values:
# Wi: 8.0
# Ni: 8.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 9.0
# backpropogating...
# New Values:
# Wi: 10.0
# Ni: 10.0
# backpropogating...
# New Values:
# Wi: 11.0
# Ni: 13.0
# backpropogating...
# Wi :  45.0
# Ni :  61.0
# Child UCB Value: 1.3277352499615351
# Child UCB Value: 1.3067385360922201
# Child UCB Value: 1.3598838966212636
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3277352499615351
# Child UCB Value: 1.4084892144838759
# Child UCB Value: 1.3385957235962236
# Move Selected: 3
# adding children
# simulating...
# Move Selected: 6
# Move Selected: 1
# Move Selected: 4
# Move Selected: 4
# Move Selected: 0
# Move Selected: 2
# Move Selected: 6
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# Wi :  46.0
# Ni :  62.0
# Child UCB Value: 1.3293706836155041
# Child UCB Value: 1.3085300638993838
# Child UCB Value: 1.360802930994918
# Child UCB Value: 3.03153498248125
# Child UCB Value: 1.3293706836155041
# Child UCB Value: 1.4096002728642296
# Child UCB Value: 1.3398035713974124
# Move Selected: 3
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 3
# Move Selected: 5
# Move Selected: 3
# Move Selected: 6
# Move Selected: 5
# Move Selected: 1
# Move Selected: 6
# Move Selected: 4
# Move Selected: 2
# Move Selected: 2
# Move Selected: 5
# Move Selected: 3
# Move Selected: 4
# Move Selected: 1
# Move Selected: 1
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# Wi :  47.0
# Ni :  63.0
# Child UCB Value: 1.3309768073770702
# Child UCB Value: 1.3102894843280937
# Child UCB Value: 1.3617054946309541
# Child UCB Value: 2.439294050288462
# Child UCB Value: 1.3309768073770702
# Child UCB Value: 1.4106914190937587
# Child UCB Value: 1.3409897724084634
# Move Selected: 3
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 0
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 4
# Move Selected: 6
# Move Selected: 4
# Move Selected: 2
# Move Selected: 0
# Move Selected: 4
# Move Selected: 0
# Move Selected: 4
# Move Selected: 2
# Move Selected: 4
# Move Selected: 6
# Move Selected: 1
# Move Selected: 5
# Move Selected: 0
# Move Selected: 5
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# Wi :  48.0
# Ni :  64.0
# Child UCB Value: 1.3325546111576978
# Child UCB Value: 1.3120178817720265
# Child UCB Value: 1.3625921438115915
# Child UCB Value: 2.177410022515475
# Child UCB Value: 1.3325546111576978
# Child UCB Value: 1.4117633256848734
# Child UCB Value: 1.342155057727445
# Move Selected: 3
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Move Selected: 0
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 6
# Move Selected: 6
# Move Selected: 5
# Move Selected: 3
# Move Selected: 1
# Move Selected: 1
# Move Selected: 3
# Move Selected: 0
# Move Selected: 1
# Move Selected: 2
# Move Selected: 0
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# Wi :  49.0
# Ni :  65.0
# Child UCB Value: 1.3341050363409113
# Child UCB Value: 1.3137162874651669
# Child UCB Value: 1.3634634075487015
# Child UCB Value: 2.021565865460426
# Child UCB Value: 1.3341050363409113
# Child UCB Value: 1.4128166321817406
# Child UCB Value: 1.3433001226121668
# Move Selected: 3
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Move Selected: 0
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 5
# Move Selected: 3
# Move Selected: 2
# Move Selected: 0
# Move Selected: 3
# Move Selected: 1
# Move Selected: 2
# Move Selected: 4
# Move Selected: 0
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# Wi :  50.0
# Ni :  66.0
# Child UCB Value: 1.335628978876234
# Child UCB Value: 1.3153856828710426
# Child UCB Value: 1.364319789322451
# Child UCB Value: 1.9153856828710425
# Child UCB Value: 1.335628978876234
# Child UCB Value: 1.4138519472622018
# Child UCB Value: 1.3444256287652052
# Move Selected: 3
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Move Selected: 0
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 2
# adding children
# simulating...
# Move Selected: 4
# Move Selected: 1
# Move Selected: 1
# Move Selected: 0
# Move Selected: 2
# Move Selected: 5
# Move Selected: 0
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 6.0
# backpropogating...
# Wi :  51.0
# Ni :  67.0
# Child UCB Value: 1.3371272921317447
# Child UCB Value: 1.317027002807547
# Child UCB Value: 1.3651617686843007
# Child UCB Value: 1.8371272921317447
# Child UCB Value: 1.3371272921317447
# Child UCB Value: 1.4148698506757031
# Child UCB Value: 1.3455322064406547
# Move Selected: 3
# Wi :  6.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.598625002690007
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  5.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Move Selected: 0
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 2
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# adding children
# simulating...
# Move Selected: 3
# Move Selected: 3
# Move Selected: 0
# Move Selected: 6
# Move Selected: 6
# Move Selected: 2
# Move Selected: 0
# Move Selected: 4
# Move Selected: 5
# Move Selected: 1
# Move Selected: 0
# Move Selected: 4
# Move Selected: 1
# Move Selected: 1
# Move Selected: 4
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 5.0
# Ni: 6.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 7.0
# backpropogating...
# Wi :  51.0
# Ni :  68.0
# Child UCB Value: 1.3386007895274235
# Child UCB Value: 1.3186411383316239
# Child UCB Value: 1.3659898027368178
# Child UCB Value: 1.6335363237724767
# Child UCB Value: 1.3386007895274235
# Child UCB Value: 1.4158708950323025
# Child UCB Value: 1.346620456388984
# Move Selected: 3
# Wi :  6.0
# Ni :  7.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4028228926545605
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# adding children
# simulating...
# Move Selected: 1
# Move Selected: 4
# Move Selected: 3
# Move Selected: 2
# Move Selected: 3
# Move Selected: 1
# Move Selected: 2
# Move Selected: 4
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 8.0
# backpropogating...
# Wi :  51.0
# Ni :  69.0
# Child UCB Value: 1.3400502469691182
# Child UCB Value: 1.3202289394055438
# Child UCB Value: 1.3668043275014476
# Child UCB Value: 1.4775048543306482
# Child UCB Value: 1.3400502469691182
# Child UCB Value: 1.416855607456223
# Child UCB Value: 1.34769095165464
# Move Selected: 3
# Wi :  6.0
# Ni :  8.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4220383445910707
# Child UCB Value: 1.442026886600883
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# adding children
# simulating...
# Move Selected: 5
# Move Selected: 3
# Move Selected: 3
# Move Selected: 2
# Move Selected: 5
# Move Selected: 6
# Move Selected: 3
# Move Selected: 4
# Move Selected: 1
# Move Selected: 6
# Move Selected: 0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 9.0
# backpropogating...
# Wi :  52.0
# Ni :  70.0
# Child UCB Value: 1.3414764051009156
# Child UCB Value: 1.3217912173642532
# Child UCB Value: 1.3676057591842354
# Child UCB Value: 1.4648403854740293
# Child UCB Value: 1.3414764051009156
# Child UCB Value: 1.4178244911160387
# Child UCB Value: 1.3487442392395312
# Move Selected: 3
# Wi :  7.0
# Ni :  9.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.438481328639195
# Child UCB Value: 1.548147073968205
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  1.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# adding children
# simulating...
# Move Selected: 2
# Move Selected: 2
# Move Selected: 4
# Move Selected: 1
# Move Selected: 1
# Move Selected: 6
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 8.0
# Ni: 10.0
# backpropogating...
# Wi :  53.0
# Ni :  71.0
# Child UCB Value: 1.342879971391866
# Child UCB Value: 1.323328747201268
# Child UCB Value: 1.3683944953484666
# Child UCB Value: 1.452892018410496
# Child UCB Value: 1.342879971391866
# Child UCB Value: 1.4187780266423244
# Child UCB Value: 1.3497808416441797
# Move Selected: 3
# Wi :  8.0
# Ni :  10.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4528203648083065
# Child UCB Value: 1.542753628292822
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  2.0
# Ni :  3.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# adding children
# simulating...
# Move Selected: 3
# Move Selected: 0
# Move Selected: 2
# Move Selected: 5
# Move Selected: 0
# Move Selected: 2
# Move Selected: 0
# Move Selected: 0
# Move Selected: 0
# Move Selected: 5
# Move Selected: 5
# Move Selected: 3
# Move Selected: 3
# Move Selected: 1
# Move Selected: 1
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 11.0
# backpropogating...
# Wi :  54.0
# Ni :  72.0
# Child UCB Value: 1.3442616220714263
# Child UCB Value: 1.3248422696888433
# Child UCB Value: 1.3691709160022896
# Child UCB Value: 1.4417103492062289
# Child UCB Value: 1.3442616220714263
# Child UCB Value: 1.4197166734425304
# Child UCB Value: 1.350801258297138
# Move Selected: 3
# Wi :  9.0
# Ni :  11.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4655114823807849
# Child UCB Value: 1.5242569458516937
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  3.0
# Ni :  4.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# adding children
# simulating...
# Move Selected: 1
# Move Selected: 2
# Move Selected: 3
# Move Selected: 5
# Move Selected: 3
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 10.0
# Ni: 12.0
# backpropogating...
# Wi :  55.0
# Ni :  73.0
# Child UCB Value: 1.345622003926537
# Child UCB Value: 1.3263324933465728
# Child UCB Value: 1.3699353846085875
# Child UCB Value: 1.431278386630345
# Child UCB Value: 1.345622003926537
# Child UCB Value: 1.4206408709218554
# Child UCB Value: 1.3518059668822189
# Move Selected: 3
# Wi :  10.0
# Ni :  12.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4768790646516292
# Child UCB Value: 1.5049690276583787
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  4.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.63431812058976
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 2
# adding children
# simulating...
# Move Selected: 3
# Move Selected: 0
# Move Selected: 2
# Move Selected: 4
# Move Selected: 1
# Move Selected: 4
# backpropogating...
# ...
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 8.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 13.0
# backpropogating...
# Wi :  67.0
# Ni :  90.0
# Child UCB Value: 1.2303381982147727
# Child UCB Value: 1.3486632353296153
# Child UCB Value: 1.3243316176648077
# Child UCB Value: 1.3575667322740124
# Child UCB Value: 1.2626473828728555
# Child UCB Value: 1.361348361430647
# Child UCB Value: 1.2806436553509355
# Move Selected: 1
# Wi :  20.0
# Ni :  22.0
# Child UCB Value: 2.758136073618398
# Child UCB Value: 1.4143966466347533
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.24318993990426
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 0
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 6
# Move Selected: 5
# Move Selected: 3
# Move Selected: 5
# Move Selected: 2
# Move Selected: 0
# Move Selected: 2
# Move Selected: 1
# Move Selected: 4
# Move Selected: 0
# Move Selected: 3
# Move Selected: 3
# Move Selected: 1
# Move Selected: 3
# Move Selected: 4
# Move Selected: 5
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 21.0
# Ni: 23.0
# backpropogating...
# Wi :  68.0
# Ni :  91.0
# Child UCB Value: 1.2313220130813238
# Child UCB Value: 1.3498273007780783
# Child UCB Value: 1.324913650389039
# Child UCB Value: 1.3582886550187352
# Child UCB Value: 1.2635150260305297
# Child UCB Value: 1.3559027407476079
# Child UCB Value: 1.2813655780956583
# Move Selected: 3
# Wi :  10.0
# Ni :  13.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.487161720279727
# Child UCB Value: 1.32049505361306
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  5.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3986250026900071
# Move Selected: 6
# adding children
# simulating...
# Move Selected: 5
# Move Selected: 0
# Move Selected: 5
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 6.0
# Ni: 7.0
# backpropogating...
# New Values:
# Wi: 11.0
# Ni: 14.0
# backpropogating...
# Wi :  69.0
# Ni :  92.0
# Child UCB Value: 1.2322938910678376
# Child UCB Value: 1.350977242319609
# Child UCB Value: 1.3254886211598045
# Child UCB Value: 1.3540318891374472
# Child UCB Value: 1.2643721418495342
# Child UCB Value: 1.3564389037559441
# Child UCB Value: 1.2820787415651425
# Move Selected: 1
# Wi :  21.0
# Ni :  23.0
# Child UCB Value: 2.2520970840811723
# Child UCB Value: 1.417365694693724
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.2520970840811725
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Move Selected: 0
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 2
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 2
# Move Selected: 0
# Move Selected: 1
# Move Selected: 3
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 21.0
# Ni: 24.0
# backpropogating...
# Wi :  69.0
# Ni :  93.0
# Child UCB Value: 1.2332541072141392
# Child UCB Value: 1.3521133853857172
# Child UCB Value: 1.3260566926928585
# Child UCB Value: 1.3547108644859018
# Child UCB Value: 1.2652189728921952
# Child UCB Value: 1.3095783153986391
# Child UCB Value: 1.2827833475834431
# Move Selected: 3
# Wi :  11.0
# Ni :  14.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4711527837279545
# Child UCB Value: 1.3298731867410774
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  6.0
# Ni :  7.0
# Child UCB Value: 2.3949588341794583
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4238445558078252
# Move Selected: 6
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# adding children
# simulating...
# Move Selected: 1
# Move Selected: 2
# Move Selected: 0
# Move Selected: 0
# Move Selected: 4
# Move Selected: 2
# Move Selected: 0
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 7.0
# Ni: 8.0
# backpropogating...
# New Values:
# Wi: 12.0
# Ni: 15.0
# backpropogating...
# Wi :  70.0
# Ni :  94.0
# Child UCB Value: 1.2342029273057182
# Child UCB Value: 1.353236044458035
# Child UCB Value: 1.3266180222290174
# Child UCB Value: 1.3503510868691007
# Child UCB Value: 1.2660557535592813
# Child UCB Value: 1.3100907368138859
# Child UCB Value: 1.2834795911837886
# Move Selected: 5
# Wi :  2.0
# Ni :  5.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.3970612889970506
# Child UCB Value: 1.2686362411795196
# Child UCB Value: 1.2686362411795196
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 3
# Move Selected: 3
# Move Selected: 2
# Move Selected: 5
# Move Selected: 4
# Move Selected: 0
# Move Selected: 6
# Move Selected: 6
# Move Selected: 4
# Move Selected: 1
# Move Selected: 3
# Move Selected: 4
# Move Selected: 2
# Move Selected: 1
# Move Selected: 5
# Move Selected: 0
# Move Selected: 3
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 6.0
# backpropogating...
# Wi :  71.0
# Ni :  95.0
# Child UCB Value: 1.2351406082809064
# Child UCB Value: 1.371194284837443
# Child UCB Value: 1.3271727617750484
# Child UCB Value: 1.3509916449215629
# Child UCB Value: 1.266882710449103
# Child UCB Value: 1.3105971424187215
# Child UCB Value: 1.2841676609073693
# Move Selected: 5
# Wi :  3.0
# Ni :  6.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 2.33856619904585
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4465092364124228
# Child UCB Value: 1.3385661990458504
# Child UCB Value: 1.3385661990458504
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# adding children
# simulating...
# Move Selected: 6
# Move Selected: 4
# Move Selected: 6
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 7.0
# backpropogating...
# Wi :  72.0
# Ni :  96.0
# Child UCB Value: 1.236067398616024
# Child UCB Value: 1.3789245414731668
# Child UCB Value: 1.3277210583315244
# Child UCB Value: 1.3516247632505172
# Child UCB Value: 1.2677000626971762
# Child UCB Value: 1.3110976664056953
# Child UCB Value: 1.2848477390859565
# Move Selected: 5
# Wi :  4.0
# Ni :  7.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.9863848511243756
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4863848511243756
# Child UCB Value: 1.3949588341794583
# Child UCB Value: 1.3949588341794583
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 3
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 2
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 0
# Move Selected: 1
# Move Selected: 4
# Move Selected: 0
# Move Selected: 0
# Move Selected: 4
# Move Selected: 2
# Move Selected: 6
# Move Selected: 3
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 8.0
# backpropogating...
# Wi :  72.0
# Ni :  97.0
# Child UCB Value: 1.2369835386898986
# Child UCB Value: 1.2562002858455708
# Child UCB Value: 1.3282630541084781
# Child UCB Value: 1.352250606065965
# Child UCB Value: 1.2685080222977003
# Child UCB Value: 1.3115924385942122
# Child UCB Value: 1.2855200021093856
# Move Selected: 3
# Wi :  12.0
# Ni :  15.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.456812921081834
# Child UCB Value: 1.3384863598758652
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  7.0
# Ni :  8.0
# Child UCB Value: 2.019666990168809
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.444894028764391
# Move Selected: 6
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 0
# Move Selected: 5
# Move Selected: 0
# Move Selected: 3
# Move Selected: 4
# Move Selected: 0
# Move Selected: 5
# Move Selected: 0
# Move Selected: 3
# Move Selected: 3
# Move Selected: 1
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 8.0
# Ni: 9.0
# backpropogating...
# New Values:
# Wi: 13.0
# Ni: 16.0
# backpropogating...
# Wi :  73.0
# Ni :  98.0
# Child UCB Value: 1.2378892611290684
# Child UCB Value: 1.2570475116092923
# Child UCB Value: 1.3287988867296252
# Child UCB Value: 1.347813429139332
# Child UCB Value: 1.2693067944079983
# Child UCB Value: 1.3120815846169611
# Child UCB Value: 1.2861846206788679
# Move Selected: 3
# Wi :  13.0
# Ni :  16.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.443925296327354
# Child UCB Value: 1.3464446601125393
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  8.0
# Ni :  9.0
# Child UCB Value: 1.8558085022044397
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4629064153161018
# Move Selected: 6
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# adding children
# simulating...
# Move Selected: 1
# Move Selected: 2
# Move Selected: 4
# Move Selected: 3
# Move Selected: 3
# Move Selected: 2
# Move Selected: 1
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 10.0
# backpropogating...
# New Values:
# Wi: 14.0
# Ni: 17.0
# backpropogating...
# Wi :  74.0
# Ni :  99.0
# Child UCB Value: 1.238784791134877
# Child UCB Value: 1.2578852032246202
# Child UCB Value: 1.3293286894258776
# Child UCB Value: 1.3434343719785664
# Child UCB Value: 1.270096577636987
# Child UCB Value: 1.3125652260965686
# Child UCB Value: 1.286841760047011
# Move Selected: 3
# Wi :  14.0
# Ni :  17.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4322793762730448
# Child UCB Value: 1.3538363866117247
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  9.0
# Ni :  10.0
# Child UCB Value: 1.7587135646925733
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4786140424415113
# Move Selected: 6
# Wi :  4.0
# Ni :  4.0
# Child UCB Value: 1.6797779934458728
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 6
# Wi :  3.0
# Ni :  3.0
# Child UCB Value: 1.7411519036837557
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# Wi :  2.0
# Ni :  2.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.8325546111576978
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 4
# Wi :  1.0
# Ni :  1.0
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Child UCB Value: 1.4142135623730951
# Move Selected: 5
# adding children
# simulating...
# Move Selected: 5
# Move Selected: 2
# Move Selected: 2
# Move Selected: 4
# Move Selected: 1
# Move Selected: 3
# Move Selected: 0
# Move Selected: 0
# Move Selected: 0
# Move Selected: 1
# Move Selected: 1
# Move Selected: 3
# Move Selected: 1
# Move Selected: 4
# Move Selected: 0
# Move Selected: 0
# Move Selected: 4
# Move Selected: 4
# backpropogating...
# New Values:
# Wi: 0
# Ni: 1.0
# backpropogating...
# New Values:
# Wi: 1.0
# Ni: 2.0
# backpropogating...
# New Values:
# Wi: 2.0
# Ni: 3.0
# backpropogating...
# New Values:
# Wi: 3.0
# Ni: 4.0
# backpropogating...
# New Values:
# Wi: 4.0
# Ni: 5.0
# backpropogating...
# New Values:
# Wi: 9.0
# Ni: 11.0
# backpropogating...
# New Values:
# Wi: 14.0
# Ni: 18.0
# backpropogating...
# Number of rollouts: 100
# Seconds elapsed:  6.851519346237183
# 4

# %%
def is_game_over(board):
      """
      Returns true or false depending on if game is over
      """
      def check_consecutive(lst):
        count = 1
        for i in range(len(lst) - 1):
          if lst[i] != 'O' and lst[i] == lst[i + 1]:
            count += 1
            if count == 4:
              return True
          else:
              count = 1
        return False

      def check_rows(board):
        for row in board:
          if check_consecutive(row):
            return True
          return False

      def check_columns(board):
        for col in range(len(board[0])):
          column = [board[row][col] for row in range(len(board))]
          if check_consecutive(column):
            return True
        return False

      def check_diagonals(board):
        for i in range(len(board) - 3):
          for j in range(len(board[0]) - 3):
            if board[i][j] != 'O' and board[i][j] == board[i + 1][j + 1] == board[i + 2][j + 2] == board[i + 3][j + 3]:
              return True
            if board[i][j + 3] != 'O' and board[i][j + 3] == board[i + 1][j + 2] == board[i + 2][j + 1] == board[i + 3][j]:
              return True
        return False

      if check_rows(board) or check_columns(board) or check_diagonals(board):
        return True

      if len(find_legal_moves(board)) == 0:
        return True
      return False

# %%
_,_, board = read_game_state('./test1.txt')

# %%
board
# Out:
# [['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'Y', 'O', 'O', 'O', 'Y'],
#  ['O', 'O', 'R', 'O', 'O', 'O', 'Y'],
#  ['O', 'Y', 'R', 'Y', 'O', 'Y', 'R'],
#  ['Y', 'R', 'R', 'Y', 'O', 'R', 'R']]

# %%
board1 = [['O', 'O', 'O', 'O', 'O', 'O', 'O'],
 ['O', 'O', 'O', 'O', 'O', 'O', 'Y'],
 ['O', 'O', 'Y', 'Y', 'O', 'O', 'Y'],
 ['O', 'O', 'R', 'R', 'O', 'O', 'Y'],
 ['O', 'Y', 'R', 'R', 'O', 'Y', 'R'],
 ['Y', 'R', 'R', 'Y', 'O', 'R', 'R']]

# %%
def game_result(board):
  """
  Checks if there is a winner in the Connect 4 board.

  Args:
    board: A 2D list representing the Connect 4 board.

  Returns:
    The player who won, or None if there is no winner.
  """

  def get_winner(player):
    if player == 'Y':
      return 1
    else:
      return -1

  # Check for horizontal wins.
  for row in board:
    for i in range(len(row) - 3):
      if row[i] == row[i + 1] == row[i + 2] == row[i + 3] and row[i] != 'O':
        return get_winner(row[i])

  # Check for vertical wins.
  for col in range(len(board[0])):
    for i in range(len(board) - 3):
      if board[i][col] == board[i + 1][col] == board[i + 2][col] == board[i + 3][col] and board[i][col] != 'O':
        return get_winner(board[i][col])

  # Check for diagonal wins.
  for i in range(len(board) - 3):
    for j in range(len(board[0]) - 3):
      if board[i][j] == board[i + 1][j + 1] == board[i + 2][j + 2] == board[i + 3][j + 3] and board[i][j] != 'O':
        return get_winner(board[i][j])

      if board[i][j + 3] == board[i + 1][j + 2] == board[i + 2][j + 1] == board[i + 3][j] and board[i][j + 3] != 'O':
        return get_winner(board[i][j + 3])

  #in case of draw
  if len(find_legal_moves(board)) == 0:
    return 0

  # If there is no winner, return None.
  return None

# %%
game_result(board1)
# Out:
# 1
