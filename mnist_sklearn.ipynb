# %% [markdown]
# # **CS 4361/5361 Machine Learning**
#
# **Classification using k-nn and the scikit-learn library**
#
# **Author:** [Olac Fuentes](http://www.cs.utep.edu/ofuentes/)<br>
# **Last modified:** 2021/09/03<br>
# Please report errors to me.

# %% [markdown]
# Scikit-learn (also known as sklearn) is a free software machine learning library for Python. It features various classification, regression and clustering algorithms including support vector machines, random forests, gradient boosting, k-means and DBSCAN, and is designed to interoperate with the Python numerical and scientific libraries NumPy and SciPy.

# %% [markdown]
# See documentation for k-nn here:
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import accuracy_score, confusion_matrix
import time

# %% [markdown]
# Download data.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = np.float32(x_train/255).reshape(x_train.shape[0],-1)
x_test = np.float32(x_test/255).reshape(x_test.shape[0],-1)

# %% [markdown]
# First we create the model. We will use the default parameters. See the documentation for details on available parameters and their default values.

# %%
model =  KNeighborsClassifier( algorithm = 'brute', weights = 'distance', n_neighbors = 5)

# %% [markdown]
# Next we train the model using the 'fit' function.

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree', weights='distance')

# %% [markdown]
# Finally we generate the predictions using the 'predict' function and show the accuracy obtained and the resulting confucion matrix.

# %%
pred = model.predict(x_test)
accuracy = accuracy_score(y_test, pred)
print(f'Accuracy {accuracy:.4}')
print(confusion_matrix(y_test, pred))

# %% [markdown]
# Here's a complete execution including running time.

# %%
start = time.time()
model =  KNeighborsClassifier(algorithm='brute', n_jobs=-1) 
start_train = time.time()
model.fit(x_train, y_train)
end_train = time.time()
print('Elapsed time training= {:.4f} secs'.format(end_train-start_train))
start_test = time.time()
pred = model.predict(x_test)
end_test = time.time()
print('Elapsed time testing= {:.4f} secs'.format(end_test-start_test))

print('Accuracy = {:.4f}'.format(accuracy_score(pred,y_test)))
print(confusion_matrix(y_test, pred))
